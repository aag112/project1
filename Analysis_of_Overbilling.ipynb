# %% [markdown]
# <a href="https://colab.research.google.com/github/aag112/project1/blob/master/Analysis_of_Overbilling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
sns.set_style('whitegrid')

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv', index_col= 'DESYNPUF_ID', parse_dates= True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(50)
# Out:
#                            CLM_ID  SEGMENT  ...  HCPCS_CD_44  HCPCS_CD_45
# DESYNPUF_ID                                 ...
# 00013D2EFD8E45D1  542192281063886        1  ...          NaN          NaN
# 00016F745862898F  542272281166593        1  ...          NaN          NaN
# 00016F745862898F  542282281644416        1  ...          NaN          NaN
# 0001FDD721E223DC  542642281250669        1  ...          NaN          NaN
# 00024B3D2352D2D0  542242281386963        1  ...          NaN          NaN
# 00024B3D2352D2D0  542442280980633        1  ...          NaN          NaN
# 00024B3D2352D2D0  542422281208985        1  ...          NaN          NaN
# 00024B3D2352D2D0  542372281246633        1  ...          NaN          NaN
# 0002F28CE057345B  542052281361022        2  ...          NaN          NaN
# 0002F28CE057345B  542162280904893        1  ...          NaN          NaN
# 0002F28CE057345B  542192281407888        1  ...          NaN          NaN
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                            CLM_ID  SEGMENT  ...  HCPCS_CD_44  HCPCS_CD_45
# DESYNPUF_ID                                 ...
# 00013D2EFD8E45D1  542192281063886        1  ...          NaN          NaN
# 00016F745862898F  542272281166593        1  ...          NaN          NaN
# 00016F745862898F  542282281644416        1  ...          NaN          NaN
# 0001FDD721E223DC  542642281250669        1  ...          NaN          NaN
# 00024B3D2352D2D0  542242281386963        1  ...          NaN          NaN
# ...                           ...      ...  ...          ...          ...
# FFFF7C107A4E385A  542672281474119        1  ...          NaN          NaN
# FFFF7C107A4E385A  542802281199642        1  ...          NaN          NaN
# FFFF7C107A4E385A  542972281048297        1  ...          NaN          NaN
# FFFF7C107A4E385A  542552281122714        1  ...          NaN          NaN
# FFFF7C107A4E385A  542542281466911        1  ...          NaN          NaN
#
# ...

# %% [markdown]
# #Changing float type dates to datetime type

# %%
df['CLM_FROM_DT'] = pd.to_datetime(df['CLM_FROM_DT'], format='%Y%m%d')
df['CLM_THRU_DT'] = pd.to_datetime(df['CLM_THRU_DT'], format='%Y%m%d')
df['CLM_FROM_DT']
# Out:
# DESYNPUF_ID
# 00013D2EFD8E45D1   2008-09-04
# 00016F745862898F   2009-06-02
# 00016F745862898F   2009-06-23
# 0001FDD721E223DC   2009-10-11
# 00024B3D2352D2D0   2008-07-12
#                       ...
# FFFF7C107A4E385A   2009-11-17
# FFFF7C107A4E385A   2010-01-22
# FFFF7C107A4E385A   2010-01-27
# FFFF7C107A4E385A   2010-01-30
# FFFF7C107A4E385A   2010-02-20
# Name: CLM_FROM_DT, Length: 790790, dtype: datetime64[ns]

# %% [markdown]
# #Dropping Procedural Codes and NaN values in certain columns

# %%
df1 = df.drop(['ICD9_PRCDR_CD_1','ICD9_PRCDR_CD_2','ICD9_PRCDR_CD_3','ICD9_PRCDR_CD_4','ICD9_PRCDR_CD_5','ICD9_PRCDR_CD_6'], axis=1)
df1
# Out:
#                            CLM_ID  SEGMENT  ... HCPCS_CD_44 HCPCS_CD_45
# DESYNPUF_ID                                 ...
# 00013D2EFD8E45D1  542192281063886        1  ...         NaN         NaN
# 00016F745862898F  542272281166593        1  ...         NaN         NaN
# 00016F745862898F  542282281644416        1  ...         NaN         NaN
# 0001FDD721E223DC  542642281250669        1  ...         NaN         NaN
# 00024B3D2352D2D0  542242281386963        1  ...         NaN         NaN
# ...                           ...      ...  ...         ...         ...
# FFFF7C107A4E385A  542672281474119        1  ...         NaN         NaN
# FFFF7C107A4E385A  542802281199642        1  ...         NaN         NaN
# FFFF7C107A4E385A  542972281048297        1  ...         NaN         NaN
# FFFF7C107A4E385A  542552281122714        1  ...         NaN         NaN
# FFFF7C107A4E385A  542542281466911        1  ...         NaN         NaN
#
# [790790 rows x 69 columns]

# %%
#drop lines with SEGMENT=2 because they contain no diagnosis codes nor procedure codes
df1 = df1[df1['SEGMENT']==1]

# %%
# we need to set missing admitting diagnosis codes to first diagnosis code
df1.ADMTNG_ICD9_DGNS_CD.fillna(df1.ICD9_DGNS_CD_1, inplace=True)

# %%
df1['ADMTNG_ICD9_DGNS_CD'].isna().sum()
# Out:
# 23

# %%
df1.ADMTNG_ICD9_DGNS_CD.fillna(df1.ICD9_DGNS_CD_2, inplace=True)

# %%
df1['ADMTNG_ICD9_DGNS_CD'].isna().sum()
# Out:
# 11

# %%
df1.ADMTNG_ICD9_DGNS_CD.fillna(df1.ICD9_DGNS_CD_3, inplace=True)

# %%
df1['ADMTNG_ICD9_DGNS_CD'].isna().sum()
# Out:
# 9

# %%
df1['ADMTNG_ICD9_DGNS_CD'].dropna(how= 'any', inplace=True)

# %%
# the remainder of null values can be set to the ICD9_DGNS_CD_2 value
df['ADMTNG_ICD9_DGNS_CD'] = df['ADMTNG_ICD9_DGNS_CD'].fillna(8020)

# %%
df['ADMTNG_ICD9_DGNS_CD'].isna().sum()
# Out:
# 0

# %%
df
# Out:
#                            CLM_ID  SEGMENT  ... HCPCS_CD_44 HCPCS_CD_45
# DESYNPUF_ID                                 ...
# 00013D2EFD8E45D1  542192281063886        1  ...         NaN         NaN
# 00016F745862898F  542272281166593        1  ...         NaN         NaN
# 00016F745862898F  542282281644416        1  ...         NaN         NaN
# 0001FDD721E223DC  542642281250669        1  ...         NaN         NaN
# 00024B3D2352D2D0  542242281386963        1  ...         NaN         NaN
# ...                           ...      ...  ...         ...         ...
# FFFF7C107A4E385A  542672281474119        1  ...         NaN         NaN
# FFFF7C107A4E385A  542802281199642        1  ...         NaN         NaN
# FFFF7C107A4E385A  542972281048297        1  ...         NaN         NaN
# FFFF7C107A4E385A  542552281122714        1  ...         NaN         NaN
# FFFF7C107A4E385A  542542281466911        1  ...         NaN         NaN
#
# [779537 rows x 69 columns]

# %%
data = df[(df.values == '99211') | (df.values == '99212') | (df.values == '99213') | (df.values == '99214') | (df.values == '99215')]

# %%
len(five['PRVDR_NUM'].unique().tolist())
# Out:
# 1782

# %%
five = df[(df.values == '99215')]

# %% [markdown]
# #Isolate Claims By Year

# %%
five['CLM_FROM_DT'].dt.year
five['Year'] = five['CLM_FROM_DT'].dt.year #add a year column
five

# %%
data_08 = five[five['CLM_FROM_DT'].dt.year == 2008]
data_09 = five[five['CLM_FROM_DT'].dt.year == 2009]
data_10 = five[five['CLM_FROM_DT'].dt.year == 2010]

# %%
#Excessive charges in 2008
excessive08 = data_08['CLM_PMT_AMT']
excessive08.sort_values(ascending=False)
# Out:
# DESYNPUF_ID
# FB43302BE44F6565    3300.0
# BA17379176A49F68    3300.0
# 334FD6BDCB015384    3300.0
# 7A58853BA46C6C49    3300.0
# 10C7B8099BC79C16    3300.0
#                      ...
# BFBC512EE5F11557     -10.0
# 7A2945A42BBDCED7     -10.0
# 1ED7CCEBFADD42C5     -20.0
# 66019E0D67F2A50C     -20.0
# FF43322931B404FD     -50.0
# Name: CLM_PMT_AMT, Length: 1525, dtype: float64

# %%
data_08.sort_values(by=['CLM_PMT_AMT','CLM_FROM_DT'], inplace=True)
print(data_08)
# Out:
#                            CLM_ID  SEGMENT  ... HCPCS_CD_45  Year
# DESYNPUF_ID                                 ...
# FF43322931B404FD  542682281011951        1  ...         NaN  2008
# 1ED7CCEBFADD42C5  542412281557051        1  ...         NaN  2008
# 66019E0D67F2A50C  542462281374461        1  ...         NaN  2008
# BFBC512EE5F11557  542262280943820        1  ...         NaN  2008
# 7A2945A42BBDCED7  542722281399387        1  ...         NaN  2008
# ...                           ...      ...  ...         ...   ...
# 81DA1EC01CB69805  542262281400632        1  ...         NaN  2008
# 389FA195BCCB794A  542212281500681        1  ...         NaN  2008
# 492098701DA5BE1A  542272281004269        1  ...         NaN  2008
# BA17379176A49F68  542722281439462        1  ...         NaN  2008
# 334FD6BDCB015384  542542281017413        1  ...         NaN  2008
#
# [1525 rows x 70 columns]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# ...

# %%
five.to_excel("output.xlsx",sheet_name='Sheet_name_1')

# %%
data.to_excel("outputotal.xlsx", sheet_name='Sheet_name_2')

# %%
# sns.lineplot(
#     x = five['PRVDR_NUM'],
#     y = five['CLM_PMT_AMT'],
# )
# sns.set(rc = {'figure.figsize': (20, 12)});

# %%
df2=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/ccs_multi_dx_tool_2015.csv')

# %%
df2.head(20)

# %%
df1[(df1 == '99215').any(axis=1)]
